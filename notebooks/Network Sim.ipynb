# %%
import src.analysis.network_sim as ns

# %%
# %load_ext autoreload
# %autoreload 2

# %%
ns.main()
# Out:
# cellular :
# running rep 0
# running rep 1
# running rep 2
# running rep 3
# running rep 4
# running rep 5
# running rep 6
# running rep 7
# running rep 8
# running rep 9
# running rep 10
# running rep 11
# running rep 12
# running rep 13
# running rep 14
# running rep 15
# running rep 16
# running rep 17
# running rep 18
# running rep 19
# running rep 20
# running rep 21
# running rep 22
# running rep 23
# running rep 24
# running rep 25
# running rep 26
# running rep 27
# running rep 28
# running rep 29
# running rep 30
# running rep 31
# running rep 32
# running rep 33
# running rep 34
# running rep 35
# running rep 36
# running rep 37
# running rep 38
# running rep 39
# running rep 40
# running rep 41
# running rep 42
# running rep 43
# running rep 44
# running rep 45
# running rep 46
# running rep 47
# running rep 48
# running rep 49
# running rep 50
# running rep 51
# running rep 52
# running rep 53
# running rep 54
# running rep 55
# running rep 56
# running rep 57
# ...
